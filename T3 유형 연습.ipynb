# %%
from scipy.stats import ttest_1samp # 단일표본 T 검정
from scipy.stats import ttest_ind # 독립표본 T 검정
from scipy.stats import ttest_rel # 대응표본 T 검정
from scipy.stats import f_oneway # 일원분산분석 (ANOVA)

from statsmodels.formula.api import logit # 로지스틱 회귀
from scipy.stats import chisquare # 카이스퀘어
from scipy.stats import poisson # 포아송 분포 
from scipy.stats import chi2_contingency # 카이스퀘어 2 
from scipy.stats import binom # 이항분포
# from scipy.stats.t import interval # 구간 설정

# 이원 분산 분석
import statsmodels.api as sm 
from statsmodels.formula.api import ols 

from statsmodels.formula.api import logit # 로지스틱 회귀 2단계

from statsmodels.formula.api import glm # 잔차이탈도 2
